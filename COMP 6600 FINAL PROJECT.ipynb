# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas import read_csv
import numpy as np

# load a single file as a numpy array
def load_file(filepath):
    dataframe = read_csv(filepath, sep='\t', skiprows=range(7)).dropna()
    return dataframe

# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # Return the list of files
    return loaded
    
a_walk_files = ['1Amar.txt', '2Amar.txt', '3Amar.txt', '4Amar.txt', '5Amar.txt', '6Amar.txt', '7Amar.txt','8Amar.txt','9Amar.txt','10Amar.txt','11Amar.txt']
n_walk_files =  ['1Nmar.txt', '2Nmar.txt', '3Nmar.txt', '4Nmar.txt', '5Nmar.txt', '6Nmar.txt', '7Nmar.txt','8Nmar.txt','9Nmar.txt','10Nmar.txt','11Nmar.txt']
a_stand_files = ['1Apie.txt', '2Apie.txt', '3Apie.txt', '4Apie.txt', '5Apie.txt', '6Apie.txt', '7Apie.txt','8Apie.txt','9Apie.txt','10Apie.txt','11Apie.txt']
n_stand_files = ['1Npie.txt', '2Npie.txt', '3Npie.txt', '4Npie.txt', '5Npie.txt', '6Npie.txt', '7Npie.txt','8Npie.txt','9Npie.txt','10Npie.txt','11Npie.txt']
a_sit_files = ['1Asen.txt', '2Asen.txt', '3Asen.txt', '4Asen.txt', '5Asen.txt', '6Asen.txt', '7Asen.txt','8Asen.txt','9Asen.txt','10Asen.txt','11Asen.txt']
n_sit_files = ['1Nsen.txt', '2Nsen.txt', '3Nsen.txt', '4Nsen.txt', '5Nsen.txt', '6Nsen.txt', '7Nsen.txt','8Nsen.txt','9Nsen.txt','10Nsen.txt','11Nsen.txt']

a_walk = load_group(a_walk_files, prefix='C:\\Users\\dholl\\OneDrive\\Documents\\AUBE Lab\\Human Aug\\Sample Data\\SEMG_Knee\\A_TXT\\')
n_walk = load_group(n_walk_files, prefix='C:\\Users\\dholl\\OneDrive\\Documents\\AUBE Lab\\Human Aug\\Sample Data\\SEMG_Knee\\N_TXT\\')
a_stand = load_group(a_stand_files, prefix='C:\\Users\\dholl\\OneDrive\\Documents\\AUBE Lab\\Human Aug\\Sample Data\\SEMG_Knee\\A_TXT\\')
n_stand = load_group(n_stand_files, prefix='C:\\Users\\dholl\\OneDrive\\Documents\\AUBE Lab\\Human Aug\\Sample Data\\SEMG_Knee\\N_TXT\\')
a_sit = load_group(a_sit_files, prefix='C:\\Users\\dholl\\OneDrive\\Documents\\AUBE Lab\\Human Aug\\Sample Data\\SEMG_Knee\\A_TXT\\')
n_sit = load_group(n_sit_files, prefix='C:\\Users\\dholl\\OneDrive\\Documents\\AUBE Lab\\Human Aug\\Sample Data\\SEMG_Knee\\N_TXT\\')
a_walk[8] = a_walk[8].drop(a_walk[8].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_walk[9] = a_walk[9].drop(a_walk[9].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_walk[10] = a_walk[10].drop(a_walk[10].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_sit[8] = a_sit[8].drop(a_sit[8].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_sit[9] = a_sit[9].drop(a_sit[9].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_sit[10] = a_sit[10].drop(a_sit[10].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_stand[8] = a_stand[8].drop(a_stand[8].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_stand[9] = a_stand[9].drop(a_stand[9].columns[5], axis=1)  # df.columns is zero-based pd.Index
a_stand[10] = a_stand[10].drop(a_stand[10].columns[5], axis=1)  # df.columns is zero-based pd.Index

# Binary classification
a_walk[0].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[0]['Y'] = 0
a_walk[1].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[1]['Y'] = 0
a_walk[2].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[2]['Y'] = 0
a_walk[3].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[3]['Y'] = 0
a_walk[4].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[4]['Y'] = 0
a_walk[5].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[5]['Y'] = 0
a_walk[6].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[6]['Y'] = 0
a_walk[7].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[7]['Y'] = 0
a_walk[8].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[8]['Y'] = 0
a_walk[9].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[9]['Y'] = 0
a_walk[10].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_walk[10]['Y'] = 0

n_walk[0].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[0]['Y'] = 1
n_walk[1].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[1]['Y'] = 1
n_walk[2].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[2]['Y'] = 1
n_walk[3].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[3]['Y'] = 1
n_walk[4].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[4]['Y'] = 1
n_walk[5].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[5]['Y'] = 1
n_walk[6].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[6]['Y'] = 1
n_walk[7].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[7]['Y'] = 1
n_walk[8].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[8]['Y'] = 1
n_walk[9].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[9]['Y'] = 1
n_walk[10].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_walk[10]['Y'] = 1

a_sit[0].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[0]['Y'] = 0
a_sit[1].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[1]['Y'] = 0
a_sit[2].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[2]['Y'] = 0
a_sit[3].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[3]['Y'] = 0
a_sit[4].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[4]['Y'] = 0
a_sit[5].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[5]['Y'] = 0
a_sit[6].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[6]['Y'] = 0
a_sit[7].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[7]['Y'] = 0
a_sit[8].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[8]['Y'] = 0
a_sit[9].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[9]['Y'] = 0
a_sit[10].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_sit[10]['Y'] = 0

n_sit[0].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[0]['Y'] = 1
n_sit[1].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[1]['Y'] = 1
n_sit[2].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[2]['Y'] = 1
n_sit[3].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[3]['Y'] = 1
n_sit[4].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[4]['Y'] = 1
n_sit[5].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[5]['Y'] = 1
n_sit[6].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[6]['Y'] = 1
n_sit[7].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[7]['Y'] = 1
n_sit[8].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[8]['Y'] = 1
n_sit[9].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[9]['Y'] = 1
n_sit[10].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_sit[10]['Y'] = 1

a_stand[0].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[0]['Y'] = 0
a_stand[1].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[1]['Y'] = 0
a_stand[2].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[2]['Y'] = 0
a_stand[3].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[3]['Y'] = 0
a_stand[4].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[4]['Y'] = 0
a_stand[5].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[5]['Y'] = 0
a_stand[6].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[6]['Y'] = 0
a_stand[7].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[7]['Y'] = 0
a_stand[8].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[8]['Y'] = 0
a_stand[9].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[9]['Y'] = 0
a_stand[10].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; a_stand[10]['Y'] = 0

n_stand[0].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[0]['Y'] = 1
n_stand[1].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[1]['Y'] = 1
n_stand[2].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[2]['Y'] = 1
n_stand[3].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[3]['Y'] = 1
n_stand[4].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[4]['Y'] = 1
n_stand[5].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[5]['Y'] = 1
n_stand[6].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[6]['Y'] = 1
n_stand[7].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[7]['Y'] = 1
n_stand[8].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[8]['Y'] = 1
n_stand[9].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[9]['Y'] = 1
n_stand[10].columns = ['Ch1','Ch2','Ch3','Ch4','KneeAngle']; n_stand[10]['Y'] = 1

# Train on first 8 normal and injured subjects, test on last 3 normal and injured subjects
stand_train = pd.concat([
                          n_stand[0], 
                          n_stand[1],
                          n_stand[2],
                          n_stand[3],
                          n_stand[4],
                          n_stand[5],
                          n_stand[6],
                          n_stand[7],
                          a_stand[0],
                          a_stand[1],
                          a_stand[2],
                          a_stand[3],
                          a_stand[4],
                          a_stand[5],
                          a_stand[6], 
                          a_stand[7]
                         ])

stand_test = pd.concat([
                        n_stand[8], 
                        a_stand[8], 
                        n_stand[9], 
                        a_stand[9], 
                        n_stand[10],
                        a_stand[10]
])

sit_train = pd.concat([n_sit[0], 
                       n_sit[1], 
                       n_sit[2], 
                       n_sit[3], 
                       n_sit[4], 
                       n_sit[5],
                       n_sit[6],
                       #n_sit[6].iloc[:round(0.7*len(n_sit[6]))],
                       n_sit[7],
                       #n_sit[7].iloc[:round(0.6*len(n_sit[7]))],
                       a_sit[0],
                       a_sit[1],
                       a_sit[2],
                       a_sit[3],
                       a_sit[4],
                       a_sit[5],
                       #a_sit[1], 
                       #a_sit[2].iloc[:round(0.5*len(a_sit[2]))],
                       #a_sit[3].iloc[:round(0.5*len(a_sit[3]))],
                       #a_sit[4].iloc[:round(0.5*len(a_sit[4]))],
                       #a_sit[5].iloc[:round(0.3*len(a_sit[5]))],
                       a_sit[6],
                       a_sit[7]
                      ])

sit_test = pd.concat([n_sit[8],                     
                      n_sit[9],
                      n_sit[10],
                      a_sit[8],
                      a_sit[9],
                      a_sit[10]
                       #n_sit[9].iloc[:round(0.8*len(n_sit[9]))],
                      #a_sit[10].iloc[:round(0.7*len(a_sit[10]))]
                     ])

walk_train = pd.concat([n_walk[0], 
                        n_walk[1],
                        n_walk[2],
                        n_walk[3],
                        n_walk[4], 
                        n_walk[5],
                        n_walk[6],
                        n_walk[7],
                        a_walk[0], 
                        a_walk[1], 
                        a_walk[2],
                        a_walk[3], 
                        a_walk[4], 
                        a_walk[5], 
                        a_walk[6],
                        a_walk[7]
                       # a_walk[0].iloc[:round(0.5*len(a_walk[0]))],
                       # a_walk[1].iloc[:round(0.65*len(a_walk[1]))],
                        #a_walk[2].iloc[:round(0.5*len(a_walk[2]))],
                       # a_walk[3].iloc[:round(0.15*len(a_walk[3]))],
                       # a_walk[4].iloc[:round(0.15*len(a_walk[4]))],
                       # a_walk[5].iloc[:round(0.15*len(a_walk[5]))], 
                       # a_walk[6].iloc[:round(0.5*len(a_walk[6]))],
                       ])                      

walk_test = pd.concat([n_walk[8],
                        n_walk[9],
                        n_walk[10],
                        a_walk[8],
                        #a_walk[9], a_walk[10] ])
                        #a_walk[8].iloc[:round(0.19*len(a_walk[8]))],
                        #a_walk[9].iloc[:round(0.25*len(a_walk[9]))],
                        #a_walk[10].iloc[:round(0.25*len(a_walk[10]))]
                      ])
            
stand_train_label = stand_train.iloc[:,5].values
stand_test_label = stand_test.iloc[:,5].values

sit_train_label = sit_train.iloc[:,5].values
sit_test_label = sit_test.iloc[:,5].values

walk_train_label = walk_train.iloc[:,5].values
walk_test_label = walk_test.iloc[:,5].values

sit_data = pd.concat([sit_train, sit_test])
sit_label = np.append(sit_train_label, sit_test_label)

#walk_train = walk_train.iloc[:,:-1]
#walk_test = walk_test.iloc[:,:-1]
sit_train = sit_train.iloc[:,:-1]
sit_test = sit_test.iloc[:,:-1]
stand_train = stand_train.iloc[:,:-1]
stand_test = stand_test.iloc[:,:-1]

walk_test
# Out:
#           Ch1     Ch2     Ch3     Ch4  KneeAngle  Y
# 0     -0.0015  0.0022  0.0022 -0.0038       43.8  1
# 1     -0.0008  0.0045  0.0000 -0.0030       43.9  1
# 2      0.0000  0.0067  0.0015 -0.0038       43.9  1
# 3      0.0007  0.0067  0.0000 -0.0030       44.0  1
# 4      0.0007  0.0052 -0.0015 -0.0015       44.1  1
# ...       ...     ...     ...     ...        ... ..
# 32074  0.0015 -0.0046  0.0000  0.0000      -40.8  0
# 32075  0.0030 -0.0060  0.0007 -0.0075      -40.5  0
# 32076  0.0037 -0.0068 -0.0008 -0.0128      -40.7  0
# 32077  0.0015 -0.0068 -0.0008 -0.0083      -40.1  0
# 32078  0.0007 -0.0075 -0.0023 -0.0053      -40.1  0
#
# [49154 rows x 6 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
walk_train_rom = []
walk_test_rom = []
fontsize=12
fig, ax = plt.subplots(1, 3)
bins = np.linspace(50, 80, 15)

# Train on first 8 subjects 
for i in np.arange(8):
    walk_train_rom_a = np.max(a_walk[i].iloc[:,-2]) - np.min(a_walk[i].iloc[:,-2])
    walk_train_rom_n = np.max(n_walk[i].iloc[:,-2]) - np.min(n_walk[i].iloc[:,-2])

    walk_train_rom.append(walk_train_rom_a)
    walk_train_rom.append(walk_train_rom_n)
    
for i in np.arange(8,11):
    walk_test_rom_a = np.max(a_walk[i].iloc[:,-2]) - np.min(a_walk[i].iloc[:,-2])
    walk_test_rom_n = np.max(n_walk[i].iloc[:,-2]) - np.min(n_walk[i].iloc[:,-2])

    walk_test_rom.append(walk_test_rom_a)
    walk_test_rom.append(walk_test_rom_n)

 #   walk_test_rom2= np.max(a_walk[i].iloc[:,-2]) - np.min(a_walk[i].iloc[:,-2])

ax[0].hist(walk_train_rom, bins, alpha = 0.6, label = 'Train', color = 'green')
ax[0].hist(walk_test_rom, bins, alpha = 0.6, label = 'Test', color = 'orange')
ax[0].set_title('Walking', fontsize=fontsize)
ax[0].set(xlabel = 'Angle (Deg.)')
ax[0].set(ylabel='Frequency')
ax[0].legend(fontsize=fontsize, loc='upper right')

########### Sitting ####################
sit_train_rom = []
sit_test_rom = []

# Train on first 8 subjects 
for i in np.arange(8):
    sit_train_rom_a = np.max(a_sit[i].iloc[:,-2]) - np.min(a_sit[i].iloc[:,-2])
    sit_train_rom_n = np.max(n_sit[i].iloc[:,-2]) - np.min(n_sit[i].iloc[:,-2])

    sit_train_rom.append(sit_train_rom_a)
    sit_train_rom.append(sit_train_rom_n)
    
for i in np.arange(8,11):
    sit_test_rom_a = np.max(a_sit[i].iloc[:,-2]) - np.min(a_sit[i].iloc[:,-2])
    sit_test_rom_n = np.max(n_sit[i].iloc[:,-2]) - np.min(n_sit[i].iloc[:,-2])

    sit_test_rom.append(sit_test_rom_a)
    sit_test_rom.append(sit_test_rom_n)

ax[1].hist(sit_train_rom, bins, alpha = 0.6, label = 'Train', color = 'green')
ax[1].hist(sit_test_rom, bins, alpha = 0.6, label = 'Test', color = 'orange')
ax[1].set_title('Sitting', fontsize=fontsize)
ax[1].set(xlabel='Angle (Deg.)')
ax[1].legend(fontsize=fontsize, loc='upper right')

############# Standing ####################### 
stand_train_rom = []
stand_test_rom = []

# Train on first 8 subjects 
for i in np.arange(8):
    stand_train_rom_a = np.max(a_stand[i].iloc[:,-2]) - np.min(a_stand[i].iloc[:,-2])
    stand_train_rom_n = np.max(n_stand[i].iloc[:,-2]) - np.min(n_stand[i].iloc[:,-2])

    stand_train_rom.append(stand_train_rom_a)
    stand_train_rom.append(stand_train_rom_n)
    
for i in np.arange(8,11):
    stand_test_rom_a = np.max(a_stand[i].iloc[:,-2]) - np.min(a_stand[i].iloc[:,-2])
    stand_test_rom_n = np.max(n_stand[i].iloc[:,-2]) - np.min(n_stand[i].iloc[:,-2])

    stand_test_rom.append(stand_test_rom_a)
    stand_test_rom.append(stand_test_rom_n)

bins3 = np.linspace(80,130,15)
ax[2].hist(stand_train_rom, bins3, alpha = 0.6, label = 'Train', color = 'green')
ax[2].hist(stand_test_rom, bins3, alpha = 0.6, label = 'Test', color = 'orange')
ax[2].set_title('Standing', fontsize=fontsize)
ax[2].set(xlabel='Angle (Deg.)')
ax[2].legend(fontsize=fontsize,loc='upper right')

ax[1].set_yticks([])
ax[2].set_yticks([])

ax[0].grid(True)
ax[1].grid(True)
ax[2].grid(True)
plt.suptitle('Knee Range of Motion Histogram', fontsize=fontsize, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Knee Range of Motion Histogram')

# %%
plt.hist(walk_train_label, alpha=0.6, label='Walking', color = 'black')
plt.hist(sit_train_label, alpha=0.6, label='Sitting')
plt.hist(stand_train_label, alpha=0.6, label='Standing')
plt.xlabel('Status (0 = Injured     1 = Healthy )', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize=fontsize, loc='upper right')
plt.title('Histogram of Injured vs. Normal instances', fontsize=fontsize, fontweight='bold')
plt.ylabel('Instances', fontsize=fontsize, fontweight='bold')
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.grid(True)

# %%
import seaborn as sns
def rolling_time_series_split(df,splits):
    n_samples = len(a_walk[0].iloc[:,4])
    folds = n_samples // splits
    indices = np.arange(n_samples)

    margin = 0
    for i in range(splits): 
        start = i * folds  
        stop = start + folds  
        temp = int(0.8 * (stop - start)) + start #If you want to change the data ratio of train/Validation, change the 0.8 part.
        yield indices[start: temp], indices[temp + margin: stop]  

fig, axes = plt.subplots(5, 1, figsize=(25, 30))  
for i, (train_index, test_index) in enumerate(rolling_time_series_split(a_walk[0].iloc[:,4],splits=5)):  
    sns.lineplot(data=a_walk[0].iloc[:,4], ax=axes[i], label='no_use',color="0.8",linewidth=6)  
    sns.lineplot(data=a_walk[0].iloc[:,4].iloc[train_index], ax=axes[i], label='train',color="b",linewidth=6)  
    sns.lineplot(data=a_walk[0].iloc[:,4].iloc[test_index], ax=axes[i], label='test',color="r",linewidth=6)  
    # Fit training and testing data here
    
    # make prediction on test set 
    sns.set(font_scale=4)

axes[0].legend()  
axes[4].set(xlabel='Time (1000 samples per second)')
axes[0].set(title='Train-test Splits using Rolling Start CV')

for i in np.arange(4):
    axes[i].set(xticklabels=[])
plt.show()

# %%
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)


from sklearn.cross_decomposition import PLSRegression
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from math import sqrt

action_num = 1

def rolling_time_series_split(df,splits):
    n_samples = len(action[action_num][num].iloc[:,4])
    folds = n_samples // splits
    indices = np.arange(n_samples)

    margin = 0
    for i in range(splits): 
        start = i * folds  
        stop = start + folds  
        temp = int(0.8 * (stop - start)) + start #If you want to change the data ratio of train/Validation, change the 0.8 part.
        yield indices[start: temp], indices[temp + margin: stop]  
lw=9
n_splits = 15
rmse_xgb = []
rmse_pls = []
rmse_dtr = []
action = [n_walk, a_walk, n_sit, a_sit, n_stand, a_stand]
for num in np.arange(11):

    for i, (train_index, test_index) in enumerate(rolling_time_series_split(action[action_num][num].iloc[:,4],splits=n_splits)):  
         # XGBoost ---------------------------------
        # fit training data to targets outputs
        xgboost = xgb.XGBRegressor(eval_metric = mean_squared_error)
        xgboost.fit(action[action_num][num].values[:,4][train_index].reshape(len(action[action_num][num].values[train_index]),1),
                   action[action_num][num].values[:,4][train_index])
        xgb_pred = xgboost.predict(action[action_num][num].values[:,-2][test_index].reshape(len(action[action_num][num].values[test_index]),1))
        xgb_mse = mean_squared_error(xgb_pred, action[action_num][num].iloc[:,4].iloc[test_index].values)
        
        # Partial Least Sq. Regression ------------
        pls = PLSRegression().fit(action[action_num][num].values[:,4][train_index].reshape(len(action[action_num][num].values[train_index]),1),
                   action[action_num][num].values[:,4][train_index])
        pls_pred = pls.predict(action[action_num][num].values[:,-2][test_index].reshape(len(action[action_num][num].values[test_index]),1))
        pls_mse = mean_squared_error(pls_pred, action[action_num][num].iloc[:,4].iloc[test_index].values)
        
        # Decision Tree Regression --------------
        dtr = DecisionTreeRegressor().fit(action[action_num][num].values[:,4][train_index].reshape(len(action[action_num][num].values[train_index]),1),
                   action[action_num][num].values[:,4][train_index])
        dtr_pred = dtr.predict(action[action_num][num].values[:,-2][test_index].reshape(len(action[action_num][num].values[test_index]),1))
        dtr_mse = mean_squared_error(dtr_pred, action[action_num][num].iloc[:,4].iloc[test_index].values)
                
        rmse_xgb.append(sqrt(xgb_mse))
        rmse_pls.append(sqrt(pls_mse))
        rmse_dtr.append(sqrt(dtr_mse))
        
    print('XGB RMSE %.2f' % np.mean(rmse_xgb))
    print('PLSR RMSE %.2f' % np.mean(rmse_pls))
    print('DTR RMSE %.2f' % np.mean(rmse_dtr))
# Out:
# XGB RMSE 1.54
# PLSR RMSE 0.00
# DTR RMSE 1.53
# XGB RMSE 1.55
# PLSR RMSE 0.00
# DTR RMSE 1.54
# XGB RMSE 1.09
# PLSR RMSE 0.00
# DTR RMSE 1.09
# XGB RMSE 0.85
# PLSR RMSE 0.00
# DTR RMSE 0.84
# XGB RMSE 0.99
# PLSR RMSE 0.00
# DTR RMSE 0.98
# XGB RMSE 0.85
# PLSR RMSE 0.00
# DTR RMSE 0.84
# XGB RMSE 1.33
# PLSR RMSE 0.00
# DTR RMSE 1.32
# XGB RMSE 1.74
# PLSR RMSE 0.00
# DTR RMSE 1.73
# XGB RMSE 1.57
# PLSR RMSE 0.00
# DTR RMSE 1.57
# XGB RMSE 1.43
# PLSR RMSE 0.00
# DTR RMSE 1.42
# XGB RMSE 1.36
# PLSR RMSE 0.00
# DTR RMSE 1.35

# %%
action_name = 'a_walk'
rmse_df_a_stand = pd.DataFrame({
    'pls_' + str(action_name) + '_0': rmse_pls[0:15],
    'pls_' + str(action_name) + '_1': rmse_pls[15:30],
    'pls_' + str(action_name) + '_2': rmse_pls[30:45],
    'pls_' + str(action_name) + '_3': rmse_pls[45:60],
    'pls_' + str(action_name) + '_4': rmse_pls[60:75],
    'pls_' + str(action_name) + '_5': rmse_pls[75:90],
    'pls_' + str(action_name) + '_6': rmse_pls[90:105],
    'pls_' + str(action_name) + '_7': rmse_pls[105:120],
    'pls_' + str(action_name) + '_8': rmse_pls[120:135],
    'pls_' + str(action_name) + '_9': rmse_pls[135:150],
    'pls_' + str(action_name) + '_10': rmse_pls[150:165],

    'xgb_' + str(action_name) + '_0': rmse_xgb[0:15],
    'xgb_' + str(action_name) + '_1': rmse_xgb[15:30],
    'xgb_' + str(action_name) + '_2': rmse_xgb[30:45],
    'xgb_' + str(action_name) + '_3': rmse_xgb[45:60],
    'xgb_' + str(action_name) + '_4': rmse_xgb[60:75],
    'xgb_' + str(action_name) + '_5': rmse_xgb[75:90],
    'xgb_' + str(action_name) + '_6': rmse_xgb[90:105],
    'xgb_' + str(action_name) + '_7': rmse_xgb[105:120],
    'xgb_' + str(action_name) + '_8': rmse_xgb[120:135],
    'xgb_' + str(action_name) + '_9': rmse_xgb[135:150],
    'xgb_' + str(action_name) + '_10': rmse_xgb[150:165],

    'dtr_' + str(action_name) + '_0': rmse_dtr[0:15],
    'dtr_' + str(action_name) + '_1': rmse_dtr[15:30],
    'dtr_' + str(action_name) + '_2': rmse_dtr[30:45],
    'dtr_' + str(action_name) + '_3': rmse_dtr[45:60],
    'dtr_' + str(action_name) + '_4': rmse_dtr[60:75],
    'dtr_' + str(action_name) + '_5': rmse_dtr[75:90],
    'dtr_' + str(action_name) + '_6': rmse_dtr[90:105],
    'dtr_' + str(action_name) + '_7': rmse_dtr[105:120],
    'dtr_' + str(action_name) + '_8': rmse_dtr[120:135],
    'dtr_' + str(action_name) + '_9': rmse_dtr[135:150],
    'dtr_' + str(action_name) + '_10': rmse_dtr[150:165],
})

#rmse_df_a_stand.to_csv(r'C:\Users\dholl\OneDrive\Documents\COMP 6600 AI\Final Project\Results\a_walk_pls_xgb_dtr.csv')

# %%
# Import Classifiers
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Evaluate the model using 10-fold cross-validation
nn_cv_scores_walk = cross_validate(MLPClassifier(), walk_test, walk_test_label, scoring=('accuracy'), cv=10)
nn_cv_scores_sit = cross_validate(MLPClassifier(), sit_test, sit_test_label, scoring=('accuracy'), cv=10)
nn_cv_scores_stand = cross_validate(MLPClassifier(), stand_test, stand_test_label, scoring=('accuracy'), cv=10)

nb_cv_scores_walk = cross_validate(GaussianNB(), walk_test, walk_test_label, scoring=('accuracy'), cv=10)
nb_cv_scores_sit = cross_validate(GaussianNB(), sit_test, sit_test_label, scoring=('accuracy'), cv=10)
nb_cv_scores_stand = cross_validate(GaussianNB(), stand_test, stand_test_label, scoring=('accuracy'), cv=10)

tree_cv_scores_walk = cross_validate(DecisionTreeClassifier(), walk_test, walk_test_label, scoring=('accuracy'), cv=10)
tree_cv_scores_sit = cross_validate(DecisionTreeClassifier(), sit_test, sit_test_label, scoring=('accuracy'), cv=10)
tree_cv_scores_stand = cross_validate(DecisionTreeClassifier(), stand_test, stand_test_label, scoring=('accuracy'), cv=10)

rf_cv_scores_walk = cross_validate(RandomForestClassifier(), walk_test, walk_test_label, scoring=('accuracy'), cv=10)
rf_cv_scores_sit = cross_validate(RandomForestClassifier(), sit_test, sit_test_label, scoring=('accuracy'), cv=10)
rf_cv_scores_stand = cross_validate(RandomForestClassifier(), stand_test, stand_test_label, scoring=('accuracy'), cv=10)

# Report Accuracy metric
nn_accuracy_walk = round(np.mean(nn_cv_scores_walk['test_score']),4) * 100
nb_accuracy_walk = round(np.mean(nb_cv_scores_walk['test_score']),4) * 100
dt_accuracy_walk = round(np.mean(tree_cv_scores_walk['test_score']),4) * 100
rf_accuracy_walk = round(np.mean(rf_cv_scores_walk['test_score']),4) * 100

nn_accuracy_stand = round(np.mean(nn_cv_scores_stand['test_score']),4) * 100
nb_accuracy_stand = round(np.mean(nb_cv_scores_stand['test_score']),4) * 100
dt_accuracy_stand = round(np.mean(tree_cv_scores_stand['test_score']),4) * 100
rf_accuracy_stand = round(np.mean(rf_cv_scores_stand['test_score']),4) * 100

nn_accuracy_sit = round(np.mean(nn_cv_scores_sit['test_score']),4) * 100
nb_accuracy_sit = round(np.mean(nb_cv_scores_sit['test_score']),4) * 100
dt_accuracy_sit = round(np.mean(tree_cv_scores_sit['test_score']),4) * 100
rf_accuracy_sit = round(np.mean(rf_cv_scores_sit['test_score']),4) * 100

# %%
# Plot learning curve (training and validation accuracy vs. amount of training data)
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

sns.set(font_scale=1)

train_sizes, train_scores, validation_scores = learning_curve(
    estimator = DecisionTreeClassifier(),
    X=walk_train,
    y=walk_train_label, train_sizes = [1, 100, 500, 2000, 50000, 100000, 150000, 200000, 275688],
    cv = 10,
    scoring = 'accuracy')

train_scores_mean = train_scores.mean(axis = 1)

validation_scores_mean = validation_scores.mean(axis = 1)

plt.plot(train_sizes, train_scores_mean*100, label = 'Training Accuracy')
plt.plot(train_sizes, validation_scores_mean*100, label = 'Validation Accuracy')
plt.ylabel('Accuracy (%)', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for Decision Tree Classifier (Walking)', fontsize = 18, y = 1.03)
plt.legend()
#plt.ylim(0,40)

# %%
lw = 3
fontsize= 30
size = 12
tick_size = 32
from matplotlib.pyplot import figure
figure(figsize=(28, 10), dpi=580)

fig, ax = plt.subplots(3,1, figsize=(18,20))

nb_accuracy_walk = round(np.mean(nb_cv_scores_walk['test_score']),4) * 100
dt_accuracy_walk = round(np.mean(tree_cv_scores_walk['test_score']),4) * 100

rf_accuracy_walk = round(np.mean(rf_cv_scores_walk['test_score']),4) * 100

# Plot Walking, sitting and standing results
ax[0].plot(nn_cv_scores_walk['test_score']*100, 'o-', markersize=size, linewidth=lw, label='MLP Accuracy = %.2f' %(nn_accuracy_walk))
ax[0].plot(nb_cv_scores_walk['test_score']*100,'o-', markersize=size, linewidth=lw, label = 'Naive Bayes = %.2f' %(nb_accuracy_walk))
ax[0].plot(tree_cv_scores_walk['test_score']*100,'o-', markersize=size, linewidth=lw, label = 'Decision Tree = %.2f' %(dt_accuracy_walk))
ax[0].plot(rf_cv_scores_walk['test_score']*100,'o-', markersize=size,  linewidth=lw, label = 'Random Forest = %.2f' %(rf_accuracy_walk))

ax[1].plot(nn_cv_scores_sit['test_score']*100, 'o-', markersize=size, linewidth=lw, label='MLP Accuracy = %.2f' %(nn_accuracy_sit))
ax[1].plot(nb_cv_scores_sit['test_score']*100,'o-', markersize=size, linewidth=lw, label = 'Naive Bayes = %.2f' %(nb_accuracy_sit))
ax[1].plot(tree_cv_scores_sit['test_score']*100,'o-', markersize=size, linewidth=lw, label = 'Decision Tree = %.2f' %(dt_accuracy_sit))
ax[1].plot(rf_cv_scores_sit['test_score']*100,'o-', markersize=size,  linewidth=lw, label = 'Random Forest = %.2f' %(rf_accuracy_sit))

ax[2].plot(nn_cv_scores_stand['test_score']*100, 'o-', markersize=size, linewidth=lw, label='MLP Accuracy = %.2f' %(nn_accuracy_stand))
ax[2].plot(nb_cv_scores_stand['test_score']*100,'o-', markersize=size, linewidth=lw, label = 'Naive Bayes = %.2f' %(nb_accuracy_stand))
ax[2].plot(tree_cv_scores_stand['test_score']*100,'o-', markersize=size, linewidth=lw, label = 'Decision Tree = %.2f' %(dt_accuracy_stand))
ax[2].plot(rf_cv_scores_stand['test_score']*100,'o-', markersize=size,  linewidth=lw, label = 'Random Forest = %.2f' %(rf_accuracy_stand))

# Increase tick label size
ax[2].tick_params(axis="x", labelsize=tick_size)

for i in np.arange(3):
    ax[i].tick_params(axis="y", labelsize=tick_size)    
    ax[i].legend(fontsize=22, loc='best')
    ax[i].grid(True)
    
# Remove tick labels of top 2 subplots
ax[0].set_xticks([])
ax[1].set_xticks([])

ax[2].set_xlabel('k-fold', fontsize=fontsize)
ax[1].set_ylabel('Classification Accuracy (%)', fontsize=40)
ax[0].tick_params(axis="y", labelsize=32)

# Add titles
ax[0].set_title('10-fold Cross Validation\nWalking', fontsize = fontsize, fontweight='bold')
ax[1].set_title('Sitting', fontsize=fontsize, fontweight='bold')
ax[2].set_title('Standing', fontsize=fontsize, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Standing')

# %%
train_len = round(0.8 * len(n_walk[0]))

fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(n_walk[0].iloc[:train_len,:-2])
axs[0, 0].set_title('Training Features (80%)')
axs[0, 1].plot(n_walk[0].iloc[train_len:,:-2])
axs[0, 1].set_title('Test Features (20%)')
axs[1, 0].plot(n_walk[0].iloc[:train_len,-2])
axs[1, 0].set_title('Train Labels (80%)')
axs[1, 1].plot(n_walk[0].iloc[train_len:,-2])
axs[1, 1].set_title('Test Labels (20%)')

axs[0,0].set(ylabel='EMG (V)')
axs[1,0].set(ylabel= 'Knee Angle (Deg.)')


# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()


#plt.plot(n_walk[0].iloc[:,:-2])
##plt.plot(n_walk[0].iloc[:train_len,:-2])
#plt.show()

# %%
subject=3
fig, axs = plt.subplots(5,1)
axs[0].plot(a_sit[subject]['Ch1'])
axs[1].plot(a_sit[subject]['Ch2'], 'tab:orange')
axs[2].plot(a_sit[subject]['Ch3'], 'tab:green')
axs[3].plot(a_sit[subject]['Ch4'],'tab:pink')
axs[4].plot(a_sit[subject]['KneeAngle'],'red',linewidth=4)
for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])
axs[2].set_ylabel('Raw Input Signals')

# %%
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from math import sqrt

fig, ax = plt.subplots(11,1)
#plt.rcParams.update({'figure.figsize':(10,7), 'figure.dpi':100})
rmse_list=[]
stdev_list=[]
#subject_num=10
for i in np.arange(11):
    train_len = round(0.8*len(n_walk[i].iloc[:,4]))
    train = n_walk[i].iloc[:train_len,4] 
    test = n_walk[i].iloc[train_len:,4]

    model = AutoReg(train, lags=100, old_names=False)
    model_fit = model.fit()

    predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
    rmse = sqrt(mean_squared_error(test, predictions))
    rmse_list.append(rmse)
    ax[i].plot(train, label = 'Train')
    ax[i].plot(np.arange(len(train), len(train) + len(test)),test, label = 'Test')
    ax[i].plot(np.arange(len(train), len(train) + len(test)), predictions, color='red', label = 'Predicted')
    #ax[i].set_ylabel('n_'+str(i))
    #ax[i].set_title('Subject %.0f (RMSE=%.3f' % (i, rmse) + ')' )
    #plt.show()
    #plot_acf(a_sit[0].iloc[:,4], lags=10)
    #autocorrelation_plot(a_sit[0])
ax[0].set_title('Mean RMSE: %.2f, stdev: %.2f' % (np.mean(rmse_list), np.std(rmse_list) ) )
plt.legend()
fig = plt.gcf()
fig.suptitle("XGBoost Baseline During Walking", fontsize=14)
print(rmse_list)

# %%
# Autoregression results
rmse_list=[]
stdev_list=[]

# Let's make 10 predictions per subject
for i in np.arange(0, 1, 0.1):
   

    train = a_walk[0].iloc[int(round(i * (len(a_walk[0])))) : int(round( i+step )), 4]      
    test = a_walk[0].iloc[int(i+step) : int((i+2*step)), 4] 

    model = AutoReg(train, lags=100, old_names=False)
    model_fit = model.fit()

    predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
    rmse = sqrt(mean_squared_error(test, predictions))
    rmse_list.append(rmse)

    plt.plot(train, label = 'Train')
    plt.plot(np.arange(len(train), len(train) + len(test)),test, label = 'Test')
    plt.plot(np.arange(len(train), len(train) + len(test)), predictions, color='red', label = 'Predicted')
    plt.ylabel('a_'+str(i))

    plt.title('Mean RMSE: %.2f, stdev: %.2f' % (np.mean(rmse_list), np.std(rmse_list) ) )
    plt.legend()
    fig = plt.gcf()
    fig.suptitle("AutoRegression Baseline During Walking", fontsize=14)
    print(rmse_list)

# %%
# Data exploration 
from matplotlib.pyplot import figure
range_a_walk_list = []
range_n_walk_list = []
figure(figsize = (10,7), dpi = 1200)
group = ['Injured', 'Normal']
for i in np.arange(11):
    range_a_walk = np.max(a_walk[i].iloc[:,4]) - np.min(a_walk[i].iloc[:,4])
    range_n_walk = np.max(n_walk[i].iloc[:,4]) - np.min(n_walk[i].iloc[:,4])
    range_a_walk_list.append(range_a_walk)
    range_n_walk_list.append(range_n_walk)
plt.boxplot([range_a_walk_list, range_n_walk_list], labels = group)
plt.ylabel('Knee Flexion Angle (deg.)')
plt.title('Knee Flexion/Extension Range of Motion \nAction = Walking')
plt.savefig(r'C:\Users\dholl\OneDrive\Documents\COMP 6600 AI\Final Project\ROM_Boxplot.png')
